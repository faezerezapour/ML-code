# %%
import cv2

# %%
image=cv2.imread("C:/Users/Raya-Center/Pictures/Saved Pictures/download.jpg")

# %%
image_size=cv2.resize(image,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)

# %%
cv2.imshow("my pic",image_size)
cv2.waitKey(0)
cv2.destroyAllWindows()
